# %% [markdown]
# #Excel with copilot

# %% [markdown]
# 1. Use Copilot to identify and summarize missing values in the dataset?
#
#  - The following columns have missing entries, with the count of missing values shown:
#
#       ![image.png](data:image/png;base64,...)
#
# 2. Use copilot to fill missing values in the Region and Category columns?
#
#       ![image.png](data:image/png;base64,...)
#
# 3. Fill missing numeric values in the Units Sold and Unit Price Columns?
#
#    ![image.png](data:image/png;base64,...)
#
# 4. Create a new calculated column Total Revenue?
#
#   ![image.png](data:image/png;base64,...)
#
# 5. Use Copilot to find the total price of Order ID = ‘ORD0123’.
#
#    The total price for ORD0123</Order ID> is 15,849.30.

# %% [markdown]
# 6.  Use Copilot to generate a summary chart of average profit by region?
#   -  Average Profit by Region:
#
#
#   ![image.png](data:image/png;base64,...)
#
# The chart visually compares the average profit across regions, with South leading and West having the lowest average profit
#
# 7. Create a pivot table summarizing total sales by category and region?
#   ![image.png](data:image/png;base64,...)
#
# 8.  Build a dashboard combining key KPIs and charts?
#
#     ![image.png](data:image/png;base64,...)
#
#     ![image.png](data:image/png;base64,...)
#
#     ![image.png](data:image/png;base64,...)
#
#     ![image.png](data:image/png;base64,...)
#
# 9. Use Copilot to generate a summary report?
#   - Summary Report
#
#   Key Performance Indicators (KPIs)
#
#   ![image.png](data:image/png;base64,...)
#
#   Top Performing Regions
#
#   ![image.png](data:image/png;base64,...)
#
#   Top Product Categories
#
#   ![image.png](data:image/png;base64,...)
#
#   Sales Channels
#
#   ![image.png](data:image/png;base64,...)
#
#   Sales Trend
#
#   Sales have been distributed across months, with notable peaks in regions such as East and West, and in categories like Beverages and Furniture.
#
#   Key Insights
#
#
#   ![image.png](data:image/png;base64,...)
